# %% [markdown]
# # <span style='background:black'><span style='color:Cyan'> <span style='font-family:"Times New Roman"'> Objective:
# ## <span style='font-family:"Times New Roman"'> This code, generates data drawn from two circular symmetric multi-variate Gaussian distributions with specific means and variance.

# %% [markdown]
# ### <span style='font-family:"Times New Roman"'>Loading Required Modules:

# %%
import matplotlib.pyplot as plt
import numpy as np
import math

# %% [markdown]
# ### <span style='font-family:"Times New Roman"'>Implemented Functions:

# %%
def circGuass(N,Me,Var):
    dimension = len(Me)
    a = np.array(Me)
    p = np.random.randn(dimension,N)
    h = np.tile(a, (2, N//2))
    x = math.sqrt(Var) * p + h
    return x

# %%
M1 = int(input("Enter first set mean : "))
M2 = int(input("Enter second set mean : "))
Var = int(input("Enter variance of data set : "))
N = int(input("Number of sample data : "))
# Out:
# Enter first set mean : 0
# Enter second set mean : 5
# Enter variance of data set : 3
# Number of sample data : 500

# %%
firstmean = [M1, M1]
secondmean = [M2, M2]
Me = firstmean;
X = circGuass(N, Me, Var)
rowonex= X[0]
rowtwox = X[1]
Me = secondmean
Y = circGuass(N, Me, Var)
rowoney= Y[0]
rowtwoy = Y[1]

# %%
plt.figure(figsize=(6,6))
fig1 = plt.figure(1)
ax1 = fig1.gca()
plt.scatter(rowonex,rowtwox , color='blue', s=10)
plt.scatter(rowoney,rowtwoy , color='blue', s=10)
ax1.set_xlim(-5,10)
ax1.set_ylim(-5,10)
plt.xlabel('$x_1$', fontsize=16)
plt.ylabel('$x_2$', fontsize=16)
plt.show()
